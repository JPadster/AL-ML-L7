# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/market_data.csv", parse_dates=True)
df = data[["Close", "Date"]]

df.head
# Out:
# <bound method NDFrame.head of         Close        Date
# 0    1,286.12  01/31/2011
# 1    1,276.34  01/28/2011
# 2    1,299.54  01/27/2011
# 3    1,296.63  01/26/2011
# 4    1,291.18  01/25/2011
# ..        ...         ...
# 248  1,066.19  02/05/2010
# 249  1,063.11  02/04/2010
# 250  1,097.28  02/03/2010
# 251  1,103.32  02/02/2010
# 252  1,089.19  02/01/2010
#
# [253 rows x 2 columns]>

# %%
fig, ax = plt.subplots()

#df['Close'] = df['Close'].astype(str).str.replace(',', '').astype(float)

df.loc[:, ('Close')] = df.loc[:, ('Close')].astype(str).str.replace(',', '').astype(float)
#df.loc['Close'] = pd.to_numeric(spx['Close'])


df

df.plot(ax=ax, color='black')

ax.plot(df['Close'], color='Red')
